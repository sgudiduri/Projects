# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from os import path
from cvxpy import *
import bs4 as bs
from urllib.request import Request, urlopen
from pathlib import Path  
from matplotlib.pyplot import figure

# %% [markdown]
# ### Maximixe $\Sigma_{i}rx_i - \gamma\Sigma_{i}\Sigma_{j}Q_{ik}x_ix_j - \Sigma_{i}ty_i$
#
# ### Where r = expected return of stock
# ### x = amount invested in stock
# ### Q = Cov Matrix

# %%
def reformat_ticker_dataframe(ticker_history):
    cols = {i:i.replace("_close","") for i in list(ticker_history.columns) if "_close" in i}
    ticker_history = ticker_history[[i for i in list(cols.keys())]]
    ticker_history = ticker_history.rename(columns=cols)
    return ticker_history        

def get_sp_index():
    sp_index_path =  Path('data/sp_index.xlsx')  
    if(sp_index_path.is_file()):
        df = pd.read_excel('data/sp_index.xlsx')
        df = df[["Company","Symbol","Weight","Price", "Chg"]]
    else:
        req = Request('https://www.slickcharts.com/sp500', headers={'User-Agent': 'Mozilla/5.0'})
        webpage = urlopen(req).read()
        soup = bs.BeautifulSoup(webpage,'lxml')
        table = soup.find('table', attrs={'class':'table table-hover table-borderless table-sm'})
        df = pd.read_html(str(table))[0]
        df = df[["Company","Symbol","Weight","Price","Chg"]]
        df.to_excel("data/sp_index.xlsx")
    return df


def get_ticker_historical(symbol_list):
    ticker_history_file = Path('data/ticker_history.xlsx')  
    if ticker_history_file.is_file():
        print("found")
        ticker_history = pd.read_excel('data/ticker_history.xlsx')
        ticker_history = ticker_history.set_index("Date")
        return reformat_ticker_dataframe(ticker_history.dropna())
    else:     
        print("not found")
        ticker_history = pd.DataFrame(list(), columns=[])   
        for i in symbol_list:
            ticker_df = yf.download(i, start="2015-03-30", end="2022-03-31")[["Close"]]    
            if len(ticker_df) > 500:        
                ticker_df = ticker_df.rename(columns={"Close": f"{i}_close"})
                ticker_history = ticker_df.join(ticker_history) 
                
        ticker_history.to_excel("data/ticker_history.xlsx")
        return reformat_ticker_dataframe(ticker_history.dropna())

# %%
sp_index = get_sp_index()
df = get_ticker_historical(list(set(sp_index["Symbol"])))
df
# Out:
# found
#                    JPM        TAP         KR        PVH        VRTX  \
# Date
# 2020-03-19   85.300003  38.509998  34.180000  33.900002  215.690002
# 2020-03-20   83.500000  36.939999  31.770000  31.570000  206.000000
# 2020-03-23   79.029999  34.560001  31.080000  29.049999  202.210007
# 2020-03-24   88.430000  37.470001  30.150000  35.520000  223.130005
# 2020-03-25   91.730003  37.540001  27.940001  37.459999  210.089996
# ...                ...        ...        ...        ...         ...
# 2022-03-24  140.690002  52.919998  56.750000  81.489998  251.699997
# 2022-03-25  141.919998  53.959999  57.000000  83.720001  253.949997
# 2022-03-28  140.869995  53.349998  57.000000  84.309998  255.720001
# 2022-03-29  141.179993  54.070000  56.389999  88.480003  257.980011
# 2022-03-30  140.539993  54.299999  56.369999  82.690002  256.519989
#
#                   LKQ         MU        KIM         ZTS        VRSN  ...  \
# Date                                                                 ...
# 2020-03-19  17.379999  36.290001  10.250000  102.330002  164.600006  ...
# 2020-03-20  16.299999  36.110001  10.630000  100.940002  157.130005  ...
# 2020-03-23  13.900000  38.250000   9.410000   92.660004  151.169998  ...
# 2020-03-24  16.959999  43.270000  10.490000  103.760002  170.529999  ...
# 2020-03-25  20.000000  42.500000  11.190000  108.209999  166.970001  ...
# ...               ...        ...        ...         ...         ...  ...
# 2022-03-24  45.400002  78.209999  24.090000  189.570007  215.110001  ...
# 2022-03-25  45.799999  78.099998  24.379999  189.429993  215.750000  ...
# 2022-03-28  45.529999  79.860001  24.379999  189.369995  219.740005  ...
# 2022-03-29  47.310001  82.050003  25.360001  192.279999  221.300003  ...
# 2022-03-30  46.770000  79.160004  25.000000  191.320007  222.119995  ...
#
#                    SO        NEE         CRL         CCI          GS  \
# Date
# 2020-03-19  50.900002  51.775002  108.760002  130.750000  149.490005
# 2020-03-20  46.360001  47.937500  105.779999  128.059998  138.410004
# 2020-03-23  43.230000  45.415001  100.500000  116.980003  134.970001
# 2020-03-24  49.040001  51.632500  110.120003  123.709999  153.600006
# 2020-03-25  50.139999  52.567501  119.349998  127.959999  155.130005
# ...               ...        ...         ...         ...         ...
# 2022-03-24  69.300003  83.699997  281.049988  175.309998  336.230011
# 2022-03-25  70.930000  83.940002  279.100006  177.580002  337.489990
# 2022-03-28  71.000000  84.430000  282.679993  180.830002  335.299988
# 2022-03-29  72.059998  84.620003  290.950012  183.869995  339.660004
# 2022-03-30  72.500000  85.500000  289.859985  184.559998  335.589996
#
#                   CTAS         PSA        KEY        WRB       FBHS
# Date
# 2020-03-19  183.000000  187.600006   9.350000  32.299999  37.720001
# 2020-03-20  175.089996  171.220001   9.190000  31.719999  36.599998
# 2020-03-23  157.059998  160.610001   8.560000  28.906668  34.830002
# 2020-03-24  173.800003  168.649994   9.770000  32.066666  40.369999
# 2020-03-25  192.330002  176.539993   9.820000  31.680000  42.410000
# ...                ...         ...        ...        ...        ...
# 2022-03-24  410.410004  373.119995  23.600000  65.339996  77.570000
# 2022-03-25  413.320007  376.000000  23.889999  65.980003  77.599998
# 2022-03-28  423.239990  383.359985  23.430000  66.260002  77.989998
# 2022-03-29  431.510010  396.470001  23.629999  66.750000  80.449997
# 2022-03-30  432.010010  396.160004  23.010000  67.080002  77.709999
#
# [513 rows x 500 columns]

# %%
mp  = df

# %%
mp.head()
# Out:
#                   JPM        TAP         KR        PVH        VRTX        LKQ  \
# Date
# 2020-03-19  85.300003  38.509998  34.180000  33.900002  215.690002  17.379999
# 2020-03-20  83.500000  36.939999  31.770000  31.570000  206.000000  16.299999
# 2020-03-23  79.029999  34.560001  31.080000  29.049999  202.210007  13.900000
# 2020-03-24  88.430000  37.470001  30.150000  35.520000  223.130005  16.959999
# 2020-03-25  91.730003  37.540001  27.940001  37.459999  210.089996  20.000000
#
#                    MU    KIM         ZTS        VRSN  ...         SO  \
# Date                                                  ...
# 2020-03-19  36.290001  10.25  102.330002  164.600006  ...  50.900002
# 2020-03-20  36.110001  10.63  100.940002  157.130005  ...  46.360001
# 2020-03-23  38.250000   9.41   92.660004  151.169998  ...  43.230000
# 2020-03-24  43.270000  10.49  103.760002  170.529999  ...  49.040001
# 2020-03-25  42.500000  11.19  108.209999  166.970001  ...  50.139999
#
#                   NEE         CRL         CCI          GS        CTAS  \
# Date
# 2020-03-19  51.775002  108.760002  130.750000  149.490005  183.000000
# 2020-03-20  47.937500  105.779999  128.059998  138.410004  175.089996
# 2020-03-23  45.415001  100.500000  116.980003  134.970001  157.059998
# 2020-03-24  51.632500  110.120003  123.709999  153.600006  173.800003
# 2020-03-25  52.567501  119.349998  127.959999  155.130005  192.330002
#
#                    PSA   KEY        WRB       FBHS
# Date
# 2020-03-19  187.600006  9.35  32.299999  37.720001
# 2020-03-20  171.220001  9.19  31.719999  36.599998
# 2020-03-23  160.610001  8.56  28.906668  34.830002
# 2020-03-24  168.649994  9.77  32.066666  40.369999
# 2020-03-25  176.539993  9.82  31.680000  42.410000
#
# [5 rows x 500 columns]

# %%
plt.figure(figsize=(10,5))
plt.plot(mp['MSFT'])
plt.plot(mp['TSLA'])
plt.plot(mp['AMZN'])
plt.legend(mp.columns,fontsize=16)
plt.xlabel("Months",fontsize=18)
plt.ylabel("Stock price (Monthly average)",fontsize=18)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.grid(True)
plt.show()

# %%
mr = mp.resample('BMS').first()
mr = mr.pct_change().dropna()
figure(figsize=(8, 6), dpi=80)
plt.plot(mr['MSFT'])
plt.plot(mr['TSLA'])
plt.plot(mr['AMZN'])
plt.show()

# %%
mr.head()
# Out:
#                  JPM       TAP        KR       PVH      VRTX       LKQ  \
# Date
# 2020-04-01 -0.011020 -0.017138 -0.107665 -0.037463  0.045389  0.100690
# 2020-05-01  0.105382  0.028269  0.047869  0.368985  0.130477  0.296916
# 2020-06-01  0.057373 -0.024409  0.016583  0.066040  0.124520  0.130592
# 2020-07-01 -0.054158 -0.076639  0.033241 -0.019530 -0.001256 -0.105882
# 2020-08-03  0.030452  0.049914  0.045576  0.054401 -0.023613  0.142743
#
#                   MU       KIM       ZTS      VRSN  ...        SO       NEE  \
# Date                                                ...
# 2020-04-01  0.099201 -0.190244  0.093716  0.065978  ... -0.014931  0.053742
# 2020-05-01  0.129606  0.277108  0.139475  0.168471  ...  0.085162  0.040416
# 2020-06-01  0.028407  0.130189  0.084764  0.068335  ...  0.060467  0.125963
# 2020-07-01  0.072508  0.077629 -0.008313 -0.039036  ... -0.083709 -0.036730
# 2020-08-03  0.013883 -0.140976  0.126248  0.007459  ...  0.021562  0.127223
#
#                  CRL       CCI        GS      CTAS       PSA       KEY  \
# Date
# 2020-04-01  0.099761  0.052314 -0.028096 -0.110984  0.048081  0.010695
# 2020-05-01  0.158682  0.136783  0.218942  0.301924 -0.062354  0.171429
# 2020-06-01  0.297496  0.110990  0.128910  0.184741  0.110707  0.070461
# 2020-07-01 -0.023690 -0.010819 -0.011804  0.067865 -0.027397 -0.013502
# 2020-08-03  0.182331 -0.045320  0.009212  0.114826 -0.016670  0.029085
#
#                  WRB      FBHS
# Date
# 2020-04-01  0.036945  0.044008
# 2020-05-01  0.024084  0.307770
# 2020-06-01  0.126531  0.191845
# 2020-07-01 -0.016046  0.016455
# 2020-08-03  0.089602  0.257092
#
# [5 rows x 500 columns]

# %%
symbols = mr.columns

# %%
(list(symbols)).index("TSLA")
# Out:
# 375

# %%
r = np.array(list(mr.mean(axis=0)))
C = np.asmatrix(np.cov(mr.T))
for j in range(len(symbols)):
    print ('%s: Exp ret = %f, Risk = %f' %(symbols[j],r[j], C[j,j]**0.5))
# Out:
# JPM: Exp ret = 0.022054, Risk = 0.070507
# TAP: Exp ret = 0.014645, Risk = 0.085843
# KR: Exp ret = 0.016601, Risk = 0.064933
# PVH: Exp ret = 0.049654, Risk = 0.139652
# VRTX: Exp ret = 0.006280, Risk = 0.083015
# LKQ: Exp ret = 0.046245, Risk = 0.103630
# MU: Exp ret = 0.041961, Risk = 0.108775
# KIM: Exp ret = 0.041423, Risk = 0.129376
# ZTS: Exp ret = 0.028783, Risk = 0.066158
# VRSN: Exp ret = 0.013688, Risk = 0.069287
# ROL: Exp ret = 0.016963, Risk = 0.080100
# C: Exp ret = 0.021465, Risk = 0.105987
# CINF: Exp ret = 0.019369, Risk = 0.084005
# CF: Exp ret = 0.060965, Risk = 0.121517
# AVB: Exp ret = 0.021760, Risk = 0.066420
# EXC: Exp ret = 0.026862, Risk = 0.055911
# EVRG: Exp ret = 0.006594, Risk = 0.070914
# ORCL: Exp ret = 0.023291, Risk = 0.051787
# HSY: Exp ret = 0.022832, Risk = 0.044707
# NTAP: Exp ret = 0.032022, Risk = 0.075691
# VRSK: Exp ret = 0.013648, Risk = 0.067261
# GM: Exp ret = 0.046196, Risk = 0.124869
# CRM: Exp ret = 0.022685, Risk = 0.113749
# AMGN: Exp ret = 0.007493, Risk = 0.069803
# SNPS: Exp ret = 0.045160, Risk = 0.084305
# MTB: Exp ret = 0.023393, Risk = 0.081017
# PFE: Exp ret = 0.023411, Risk = 0.094262
# WFC: Exp ret = 0.028440, Risk = 0.097156
# DLR: Exp ret = 0.005672, Risk = 0.075716
# VTR: Exp ret = 0.046181, Risk = 0.098534
# MA: Exp ret = 0.021981, Risk = 0.097988
# BBWI: Exp ret = 0.088870, Risk = 0.176006
# PLD: Exp ret = 0.037479, Risk = 0.074047
# WYNN: Exp ret = 0.036515, Risk = 0.172447
# PKG: Exp ret = 0.022420, Risk = 0.068011
# NVDA: Exp ret = 0.070462, Risk = 0.121493
# LDOS: Exp ret = 0.017303, Risk = 0.089730
# PRU: Exp ret = 0.039801, Risk = 0.080894
# EIX: Exp ret = 0.013200, Risk = 0.066009
# REG: Exp ret = 0.027124, Risk = 0.095293
# INTU: Exp ret = 0.036184, Risk = 0.083949
# BBY: Exp ret = 0.029426, Risk = 0.108296
# RJF: Exp ret = 0.037866, Risk = 0.073227
# CDW: Exp ret = 0.030263, Risk = 0.076652
# NTRS: Exp ret = 0.021506, Risk = 0.070825
# CL: Exp ret = 0.006495, Risk = 0.045825
# CTXS: Exp ret = -0.003827, Risk = 0.096112
# RTX: Exp ret = 0.031157, Risk = 0.081451
# INTC: Exp ret = 0.004566, Risk = 0.088047
# NLSN: Exp ret = 0.011480, Risk = 0.108759
# WMB: Exp ret = 0.050635, Risk = 0.106992
# RL: Exp ret = 0.028438, Risk = 0.099929
# ENPH: Exp ret = 0.102037, Risk = 0.219041
# FCX: Exp ret = 0.100304, Risk = 0.132780
# MPC: Exp ret = 0.073374, Risk = 0.141456
# ITW: Exp ret = 0.020290, Risk = 0.064262
# STE: Exp ret = 0.031389, Risk = 0.080176
# EOG: Exp ret = 0.063189, Risk = 0.144830
# SCHW: Exp ret = 0.041194, Risk = 0.082968
# HII: Exp ret = 0.010632, Risk = 0.076737
# FFIV: Exp ret = 0.034073, Risk = 0.103385
# AWK: Exp ret = 0.013619, Risk = 0.068045
# ARE: Exp ret = 0.016844, Risk = 0.065858
# AIZ: Exp ret = 0.031152, Risk = 0.071564
# SNA: Exp ret = 0.029378, Risk = 0.074133
# ADP: Exp ret = 0.025193, Risk = 0.068295
# TXN: Exp ret = 0.022589, Risk = 0.058244
# AKAM: Exp ret = 0.010654, Risk = 0.066254
# MGM: Exp ret = 0.086590, Risk = 0.179936
# CMS: Exp ret = 0.006124, Risk = 0.049457
# TDG: Exp ret = 0.037104, Risk = 0.105147
# T: Exp ret = -0.009960, Risk = 0.059104
# BWA: Exp ret = 0.029950, Risk = 0.092787
# EFX: Exp ret = 0.032310, Risk = 0.107458
# CSCO: Exp ret = 0.018595, Risk = 0.080998
# TFX: Exp ret = 0.015725, Risk = 0.095860
# TSN: Exp ret = 0.024840, Risk = 0.060761
# GRMN: Exp ret = 0.022000, Risk = 0.080001
# PEG: Exp ret = 0.022655, Risk = 0.059541
# CARR: Exp ret = 0.059943, Risk = 0.102200
# LYV: Exp ret = 0.062351, Risk = 0.138485
# LMT: Exp ret = 0.017804, Risk = 0.067687
# HWM: Exp ret = 0.036652, Risk = 0.110560
# QRVO: Exp ret = 0.029741, Risk = 0.105892
# VMC: Exp ret = 0.030204, Risk = 0.071174
# MSFT: Exp ret = 0.032569, Risk = 0.063212
# MCK: Exp ret = 0.034004, Risk = 0.065721
# PG: Exp ret = 0.014505, Risk = 0.043797
# SWK: Exp ret = 0.029656, Risk = 0.078275
# ROST: Exp ret = 0.017822, Risk = 0.098617
# TEL: Exp ret = 0.041279, Risk = 0.077548
# JNJ: Exp ret = 0.011851, Risk = 0.049886
# DLTR: Exp ret = 0.033182, Risk = 0.100077
# GLW: Exp ret = 0.028227, Risk = 0.082388
# CMA: Exp ret = 0.051221, Risk = 0.094180
# TT: Exp ret = 0.029366, Risk = 0.082629
# NDAQ: Exp ret = 0.029624, Risk = 0.061724
# TDY: Exp ret = 0.030487, Risk = 0.090893
# CAG: Exp ret = 0.012875, Risk = 0.057438
# CERN: Exp ret = 0.022042, Risk = 0.084555
# MOH: Exp ret = 0.043083, Risk = 0.078564
# WY: Exp ret = 0.039946, Risk = 0.080721
# DISH: Exp ret = 0.026788, Risk = 0.162289
# WEC: Exp ret = 0.001167, Risk = 0.059424
# BA: Exp ret = 0.037356, Risk = 0.139250
# SJM: Exp ret = 0.007350, Risk = 0.050112
# LYB: Exp ret = 0.036803, Risk = 0.096382
# SBNY: Exp ret = 0.063683, Risk = 0.161653
# CFG: Exp ret = 0.047334, Risk = 0.088968
# RHI: Exp ret = 0.049340, Risk = 0.081052
# PWR: Exp ret = 0.063520, Risk = 0.093560
# CMI: Exp ret = 0.024525, Risk = 0.084058
# ULTA: Exp ret = 0.045973, Risk = 0.125696
# CME: Exp ret = 0.018985, Risk = 0.062848
# SIVB: Exp ret = 0.058447, Risk = 0.125984
# CBOE: Exp ret = 0.016333, Risk = 0.061512
# LOW: Exp ret = 0.053200, Risk = 0.095357
# DVA: Exp ret = 0.022432, Risk = 0.091193
# GILD: Exp ret = -0.009240, Risk = 0.060180
# MAA: Exp ret = 0.031767, Risk = 0.056295
# AMAT: Exp ret = 0.055484, Risk = 0.113004
# WAB: Exp ret = 0.033395, Risk = 0.071310
# ADSK: Exp ret = 0.021265, Risk = 0.114660
# IPG: Exp ret = 0.041652, Risk = 0.073235
# QCOM: Exp ret = 0.044274, Risk = 0.106263
# TRMB: Exp ret = 0.046703, Risk = 0.095515
# DG: Exp ret = 0.016212, Risk = 0.063267
# HIG: Exp ret = 0.032494, Risk = 0.089411
# ILMN: Exp ret = 0.022362, Risk = 0.114775
# JCI: Exp ret = 0.039484, Risk = 0.069890
# UAL: Exp ret = 0.037139, Risk = 0.138881
# HAL: Exp ret = 0.098059, Risk = 0.185527
# BKR: Exp ret = 0.051979, Risk = 0.137096
# STX: Exp ret = 0.039907, Risk = 0.087375
# ZBH: Exp ret = 0.019034, Risk = 0.092513
# GPN: Exp ret = 0.005420, Risk = 0.112488
# RSG: Exp ret = 0.022146, Risk = 0.054051
# OTIS: Exp ret = 0.024340, Risk = 0.058164
# NI: Exp ret = 0.009880, Risk = 0.053098
# MSI: Exp ret = 0.017687, Risk = 0.067526
# TMUS: Exp ret = 0.021103, Risk = 0.076621
# BAX: Exp ret = 0.004578, Risk = 0.057166
# UA: Exp ret = 0.031765, Risk = 0.099697
# DOW: Exp ret = 0.033706, Risk = 0.091058
# BAC: Exp ret = 0.032683, Risk = 0.084807
# BDX: Exp ret = 0.010524, Risk = 0.063623
# EBAY: Exp ret = 0.031313, Risk = 0.113350
# BMY: Exp ret = 0.015579, Risk = 0.051933
# UPS: Exp ret = 0.036567, Risk = 0.099299
# VTRS: Exp ret = -0.009437, Risk = 0.110323
# SPG: Exp ret = 0.044327, Risk = 0.125532
# DD: Exp ret = 0.040604, Risk = 0.093630
# AMP: Exp ret = 0.049009, Risk = 0.086488
# HBAN: Exp ret = 0.029655, Risk = 0.083030
# DXC: Exp ret = 0.044431, Risk = 0.125996
# CE: Exp ret = 0.035225, Risk = 0.083807
# EW: Exp ret = 0.030564, Risk = 0.097720
# DVN: Exp ret = 0.110022, Risk = 0.187953
# LLY: Exp ret = 0.030123, Risk = 0.088173
# GL: Exp ret = 0.019527, Risk = 0.072105
# RMD: Exp ret = 0.029246, Risk = 0.085657
# ABMD: Exp ret = 0.041264, Risk = 0.125100
# CVX: Exp ret = 0.045550, Risk = 0.103809
# NFLX: Exp ret = 0.010793, Risk = 0.094568
# STZ: Exp ret = 0.025746, Risk = 0.073700
# SBUX: Exp ret = 0.018810, Risk = 0.075602
# DUK: Exp ret = 0.013467, Risk = 0.056609
# TTWO: Exp ret = 0.020755, Risk = 0.088513
# FRC: Exp ret = 0.028701, Risk = 0.085753
# HCA: Exp ret = 0.051510, Risk = 0.098944
# NOW: Exp ret = 0.034149, Risk = 0.089366
# NSC: Exp ret = 0.029304, Risk = 0.079644
# HOLX: Exp ret = 0.041458, Risk = 0.136305
# MRNA: Exp ret = 0.110417, Risk = 0.322492
# LNT: Exp ret = 0.011664, Risk = 0.058532
# RCL: Exp ret = 0.071059, Risk = 0.220650
# RF: Exp ret = 0.046047, Risk = 0.096854
# WHR: Exp ret = 0.043117, Risk = 0.112324
# COO: Exp ret = 0.019242, Risk = 0.065265
# SWKS: Exp ret = 0.027301, Risk = 0.098648
# WELL: Exp ret = 0.031188, Risk = 0.059740
# PAYC: Exp ret = 0.030061, Risk = 0.129857
# MDT: Exp ret = 0.013116, Risk = 0.062445
# VZ: Exp ret = 0.000651, Risk = 0.037125
# HST: Exp ret = 0.026243, Risk = 0.099273
# FLT: Exp ret = 0.011761, Risk = 0.107856
# DOV: Exp ret = 0.034624, Risk = 0.070671
# PNW: Exp ret = 0.002777, Risk = 0.062829
# O: Exp ret = 0.015871, Risk = 0.053881
# HPQ: Exp ret = 0.039916, Risk = 0.086014
# MS: Exp ret = 0.048715, Risk = 0.097738
# DE: Exp ret = 0.049505, Risk = 0.077882
# SYK: Exp ret = 0.026561, Risk = 0.078715
# NVR: Exp ret = 0.028564, Risk = 0.088455
# FMC: Exp ret = 0.025181, Risk = 0.070659
# TJX: Exp ret = 0.020971, Risk = 0.080674
# KMX: Exp ret = 0.040371, Risk = 0.127788
# FDS: Exp ret = 0.025626, Risk = 0.064500
# ZBRA: Exp ret = 0.040523, Risk = 0.126535
# ED: Exp ret = 0.004191, Risk = 0.056962
# FB: Exp ret = 0.019627, Risk = 0.121132
# WBD: Exp ret = 0.022484, Risk = 0.156121
# PAYX: Exp ret = 0.031422, Risk = 0.057531
# PHM: Exp ret = 0.045824, Risk = 0.123888
# MRO: Exp ret = 0.098910, Risk = 0.232147
# KO: Exp ret = 0.017730, Risk = 0.050710
# CTRA: Exp ret = 0.021027, Risk = 0.114285
# L: Exp ret = 0.021492, Risk = 0.059694
# PNC: Exp ret = 0.033171, Risk = 0.085456
# CNC: Exp ret = 0.021161, Risk = 0.077028
# NEM: Exp ret = 0.025785, Risk = 0.101382
# NWSA: Exp ret = 0.040273, Risk = 0.121639
# AMT: Exp ret = 0.006576, Risk = 0.077158
# AAP: Exp ret = 0.039659, Risk = 0.090251
# LW: Exp ret = 0.014894, Risk = 0.089591
# FTNT: Exp ret = 0.064001, Risk = 0.111755
# IR: Exp ret = 0.041872, Risk = 0.089821
# JKHY: Exp ret = 0.010074, Risk = 0.069116
# CCL: Exp ret = 0.047964, Risk = 0.224045
# UHS: Exp ret = 0.025887, Risk = 0.084137
# AMZN: Exp ret = 0.022722, Risk = 0.077257
# ATO: Exp ret = 0.006399, Risk = 0.062873
# IRM: Exp ret = 0.031662, Risk = 0.077705
# EXPD: Exp ret = 0.025917, Risk = 0.070063
# F: Exp ret = 0.063216, Risk = 0.122307
# GD: Exp ret = 0.030448, Risk = 0.059755
# WAT: Exp ret = 0.027573, Risk = 0.086117
# AFL: Exp ret = 0.035634, Risk = 0.078860
# HAS: Exp ret = 0.034125, Risk = 0.109649
# MKC: Exp ret = 0.019794, Risk = 0.063095
# DIS: Exp ret = 0.022297, Risk = 0.096857
# APH: Exp ret = 0.034795, Risk = 0.071182
# ADM: Exp ret = 0.037282, Risk = 0.054565
# FOXA: Exp ret = 0.027629, Risk = 0.074312
# MMM: Exp ret = 0.003730, Risk = 0.057360
# A: Exp ret = 0.031902, Risk = 0.072938
# TMO: Exp ret = 0.030550, Risk = 0.076439
# TWTR: Exp ret = 0.027816, Risk = 0.160942
# MOS: Exp ret = 0.086381, Risk = 0.119756
# MET: Exp ret = 0.040729, Risk = 0.088637
# LHX: Exp ret = 0.022024, Risk = 0.072619
# SEE: Exp ret = 0.049382, Risk = 0.073282
# DXCM: Exp ret = 0.036931, Risk = 0.131180
# CHTR: Exp ret = 0.020304, Risk = 0.078976
# WM: Exp ret = 0.017846, Risk = 0.060405
# MAS: Exp ret = 0.025360, Risk = 0.088635
# JBHT: Exp ret = 0.039444, Risk = 0.074840
# CPRT: Exp ret = 0.026183, Risk = 0.082518
# TECH: Exp ret = 0.043219, Risk = 0.090209
# MDLZ: Exp ret = 0.015836, Risk = 0.051999
# AON: Exp ret = 0.029937, Risk = 0.072103
# ABBV: Exp ret = 0.032811, Risk = 0.064218
# AIG: Exp ret = 0.049112, Risk = 0.106378
# CMG: Exp ret = 0.050155, Risk = 0.125037
# KEYS: Exp ret = 0.027696, Risk = 0.083154
# SLB: Exp ret = 0.051404, Risk = 0.141009
# PGR: Exp ret = 0.019788, Risk = 0.058629
# AXP: Exp ret = 0.039020, Risk = 0.088515
# MKTX: Exp ret = 0.012891, Risk = 0.108029
# XYL: Exp ret = 0.015969, Risk = 0.085242
# MTD: Exp ret = 0.030493, Risk = 0.075422
# INCY: Exp ret = 0.005185, Risk = 0.092860
# LNC: Exp ret = 0.059687, Risk = 0.147496
# USB: Exp ret = 0.022722, Risk = 0.071392
# CBRE: Exp ret = 0.040942, Risk = 0.086094
# CHRW: Exp ret = 0.023296, Risk = 0.074321
# MLM: Exp ret = 0.035156, Risk = 0.071131
# CZR: Exp ret = 0.135881, Risk = 0.288548
# NXPI: Exp ret = 0.040411, Risk = 0.088851
# HSIC: Exp ret = 0.026142, Risk = 0.080326
# ORLY: Exp ret = 0.037161, Risk = 0.078092
# EA: Exp ret = 0.017259, Risk = 0.071667
# AZO: Exp ret = 0.036797, Risk = 0.088805
# PEP: Exp ret = 0.014576, Risk = 0.045584
# ABC: Exp ret = 0.023048, Risk = 0.064447
# CAT: Exp ret = 0.026687, Risk = 0.072691
# APA: Exp ret = 0.131313, Risk = 0.394512
# COF: Exp ret = 0.052642, Risk = 0.109487
# LEN: Exp ret = 0.052127, Risk = 0.130925
# GNRC: Exp ret = 0.065468, Risk = 0.151425
# MCD: Exp ret = 0.021083, Risk = 0.051661
# PPG: Exp ret = 0.025171, Risk = 0.091622
# PENN: Exp ret = 0.135093, Risk = 0.338072
# MSCI: Exp ret = 0.034889, Risk = 0.085128
# POOL: Exp ret = 0.040846, Risk = 0.093412
# MPWR: Exp ret = 0.049511, Risk = 0.093293
# OKE: Exp ret = 0.057540, Risk = 0.146601
# ETN: Exp ret = 0.031424, Risk = 0.059302
# HUM: Exp ret = 0.025897, Risk = 0.093078
# AES: Exp ret = 0.029847, Risk = 0.082843
# IP: Exp ret = 0.017786, Risk = 0.068908
# TROW: Exp ret = 0.016756, Risk = 0.088676
# OXY: Exp ret = 0.081479, Risk = 0.207069
# NWS: Exp ret = 0.041646, Risk = 0.120596
# XOM: Exp ret = 0.040321, Risk = 0.105018
# PARA: Exp ret = 0.053149, Risk = 0.168741
# YUM: Exp ret = 0.030093, Risk = 0.075946
# ROP: Exp ret = 0.018951, Risk = 0.069823
# J: Exp ret = 0.022451, Risk = 0.055793
# DHR: Exp ret = 0.036240, Risk = 0.081947
# WMT: Exp ret = 0.007089, Risk = 0.059739
# CTVA: Exp ret = 0.034529, Risk = 0.063027
# AAL: Exp ret = 0.026870, Risk = 0.127908
# ESS: Exp ret = 0.019500, Risk = 0.068170
# PPL: Exp ret = 0.008666, Risk = 0.061037
# HON: Exp ret = 0.020417, Risk = 0.068131
# BXP: Exp ret = 0.017894, Risk = 0.088500
# DTE: Exp ret = 0.022582, Risk = 0.056369
# AME: Exp ret = 0.027783, Risk = 0.064445
# DRI: Exp ret = 0.058008, Risk = 0.131841
# MHK: Exp ret = 0.037019, Risk = 0.115957
# GOOG: Exp ret = 0.039548, Risk = 0.070330
# GE: Exp ret = 0.029019, Risk = 0.104250
# BKNG: Exp ret = 0.029189, Risk = 0.112630
# SYF: Exp ret = 0.045972, Risk = 0.090706
# EPAM: Exp ret = 0.027294, Risk = 0.160512
# RE: Exp ret = 0.019822, Risk = 0.070356
# APD: Exp ret = 0.011035, Risk = 0.081739
# EMR: Exp ret = 0.030258, Risk = 0.067695
# ISRG: Exp ret = 0.036561, Risk = 0.094430
# CAH: Exp ret = 0.011363, Risk = 0.086232
# OMC: Exp ret = 0.019855, Risk = 0.084716
# GOOGL: Exp ret = 0.039593, Risk = 0.069381
# SPGI: Exp ret = 0.029406, Risk = 0.077468
# GIS: Exp ret = 0.010382, Risk = 0.051283
# NUE: Exp ret = 0.069168, Risk = 0.125006
# ALL: Exp ret = 0.022275, Risk = 0.071536
# AOS: Exp ret = 0.028418, Risk = 0.085432
# SBAC: Exp ret = 0.013400, Risk = 0.074335
# FAST: Exp ret = 0.022041, Risk = 0.070922
# LVS: Exp ret = 0.007220, Risk = 0.123635
# WTW: Exp ret = 0.018674, Risk = 0.086354
# HD: Exp ret = 0.032193, Risk = 0.082879
# AMCR: Exp ret = 0.019112, Risk = 0.059503
# PCAR: Exp ret = 0.021786, Risk = 0.068546
# HRL: Exp ret = 0.003233, Risk = 0.051635
# DRE: Exp ret = 0.028569, Risk = 0.066145
# ZION: Exp ret = 0.040638, Risk = 0.092041
# ETSY: Exp ret = 0.085130, Risk = 0.224257
# SYY: Exp ret = 0.040730, Risk = 0.106227
# PM: Exp ret = 0.019225, Risk = 0.054911
# TPR: Exp ret = 0.057403, Risk = 0.154679
# KMB: Exp ret = 0.001862, Risk = 0.048493
# IEX: Exp ret = 0.019558, Risk = 0.059405
# PTC: Exp ret = 0.038317, Risk = 0.105971
# MO: Exp ret = 0.015612, Risk = 0.061832
# MCHP: Exp ret = 0.039193, Risk = 0.106595
# CDAY: Exp ret = 0.025246, Risk = 0.120732
# ABT: Exp ret = 0.021808, Risk = 0.071512
# VFC: Exp ret = 0.003319, Risk = 0.097336
# PFG: Exp ret = 0.042456, Risk = 0.088397
# TRV: Exp ret = 0.029925, Risk = 0.060595
# CHD: Exp ret = 0.017565, Risk = 0.064639
# PXD: Exp ret = 0.064806, Risk = 0.108530
# CTLT: Exp ret = 0.045241, Risk = 0.118553
# EQIX: Exp ret = 0.013160, Risk = 0.069994
# URI: Exp ret = 0.064225, Risk = 0.099608
# NOC: Exp ret = 0.020183, Risk = 0.069040
# FRT: Exp ret = 0.021831, Risk = 0.089165
# EXR: Exp ret = 0.035855, Risk = 0.069809
# IFF: Exp ret = 0.010950, Risk = 0.088640
# FDX: Exp ret = 0.033384, Risk = 0.112132
# LH: Exp ret = 0.040487, Risk = 0.099418
# BLL: Exp ret = 0.017762, Risk = 0.070125
# WST: Exp ret = 0.046538, Risk = 0.091052
# DHI: Exp ret = 0.052004, Risk = 0.129275
# DAL: Exp ret = 0.030508, Risk = 0.124833
# FISV: Exp ret = 0.008787, Risk = 0.080070
# VLO: Exp ret = 0.044621, Risk = 0.167260
# PKI: Exp ret = 0.045514, Risk = 0.096275
# CI: Exp ret = 0.023710, Risk = 0.087000
# UNH: Exp ret = 0.034853, Risk = 0.068390
# TXT: Exp ret = 0.047006, Risk = 0.084698
# PH: Exp ret = 0.047467, Risk = 0.099642
# MTCH: Exp ret = 0.039192, Risk = 0.115754
# TSLA: Exp ret = 0.122618, Risk = 0.229856
# APTV: Exp ret = 0.052697, Risk = 0.128180
# GWW: Exp ret = 0.031357, Risk = 0.072156
# IVZ: Exp ret = 0.036041, Risk = 0.120104
# LUMN: Exp ret = 0.005655, Risk = 0.096386
# UNP: Exp ret = 0.031407, Risk = 0.070586
# PNR: Exp ret = 0.038480, Risk = 0.085616
# BEN: Exp ret = 0.019763, Risk = 0.094505
# MAR: Exp ret = 0.045428, Risk = 0.128469
# PYPL: Exp ret = 0.017480, Risk = 0.153538
# ODFL: Exp ret = 0.048451, Risk = 0.087408
# ALB: Exp ret = 0.055911, Risk = 0.142962
# CPT: Exp ret = 0.033096, Risk = 0.056688
# ROK: Exp ret = 0.031443, Risk = 0.086728
# NWL: Exp ret = 0.028514, Risk = 0.076912
# MRK: Exp ret = 0.006857, Risk = 0.058970
# AVY: Exp ret = 0.023471, Risk = 0.080804
# NLOK: Exp ret = 0.027480, Risk = 0.101438
# IBM: Exp ret = 0.012226, Risk = 0.071438
# CLX: Exp ret = -0.009488, Risk = 0.065755
# BIO: Exp ret = 0.028946, Risk = 0.101212
# COST: Exp ret = 0.024218, Risk = 0.056377
# CB: Exp ret = 0.032433, Risk = 0.075115
# EMN: Exp ret = 0.047491, Risk = 0.095451
# FOX: Exp ret = 0.025422, Risk = 0.075071
# UAA: Exp ret = 0.032300, Risk = 0.106527
# CTSH: Exp ret = 0.030043, Risk = 0.097924
# V: Exp ret = 0.016446, Risk = 0.082210
# AEE: Exp ret = 0.008329, Risk = 0.054971
# FITB: Exp ret = 0.056051, Risk = 0.092195
# STT: Exp ret = 0.027152, Risk = 0.090896
# ANTM: Exp ret = 0.037396, Risk = 0.082835
# ALGN: Exp ret = 0.061115, Risk = 0.129551
# IDXX: Exp ret = 0.047819, Risk = 0.096550
# NDSN: Exp ret = 0.030638, Risk = 0.074692
# MNST: Exp ret = 0.021294, Risk = 0.086053
# REGN: Exp ret = 0.012008, Risk = 0.080118
# BLK: Exp ret = 0.027700, Risk = 0.078786
# COP: Exp ret = 0.065319, Risk = 0.137651
# ANET: Exp ret = 0.047409, Risk = 0.113908
# ECL: Exp ret = 0.006963, Risk = 0.096506
# PEAK: Exp ret = 0.020396, Risk = 0.072815
# UDR: Exp ret = 0.021860, Risk = 0.063262
# TYL: Exp ret = 0.023401, Risk = 0.088693
# SHW: Exp ret = 0.026046, Risk = 0.081979
# TFC: Exp ret = 0.031206, Risk = 0.084374
# FTV: Exp ret = 0.022723, Risk = 0.062449
# ADI: Exp ret = 0.025649, Risk = 0.072767
# IT: Exp ret = 0.049860, Risk = 0.091620
# WBA: Exp ret = 0.000396, Risk = 0.088042
# KLAC: Exp ret = 0.045450, Risk = 0.094424
# XRAY: Exp ret = 0.021389, Risk = 0.079588
# LRCX: Exp ret = 0.049792, Risk = 0.119098
# ATVI: Exp ret = 0.021940, Risk = 0.099946
# D: Exp ret = 0.005740, Risk = 0.058864
# WDC: Exp ret = 0.025774, Risk = 0.119635
# AJG: Exp ret = 0.036684, Risk = 0.063572
# CNP: Exp ret = 0.035478, Risk = 0.068107
# CVS: Exp ret = 0.027572, Risk = 0.062627
# HLT: Exp ret = 0.042339, Risk = 0.097902
# ADBE: Exp ret = 0.021887, Risk = 0.095764
# TER: Exp ret = 0.045664, Risk = 0.127856
# DFS: Exp ret = 0.064541, Risk = 0.104838
# MCO: Exp ret = 0.027938, Risk = 0.078827
# EXPE: Exp ret = 0.065179, Risk = 0.128562
# NKE: Exp ret = 0.030053, Risk = 0.085751
# ALLE: Exp ret = 0.010351, Risk = 0.067561
# ALK: Exp ret = 0.039661, Risk = 0.125482
# FE: Exp ret = 0.009286, Risk = 0.081585
# XEL: Exp ret = 0.007074, Risk = 0.053226
# AMD: Exp ret = 0.054277, Risk = 0.148315
# ETR: Exp ret = 0.011244, Risk = 0.070838
# KHC: Exp ret = 0.026038, Risk = 0.077729
# BSX: Exp ret = 0.020583, Risk = 0.074768
# DGX: Exp ret = 0.027167, Risk = 0.113041
# PSX: Exp ret = 0.033376, Risk = 0.139019
# LIN: Exp ret = 0.028083, Risk = 0.072453
# BK: Exp ret = 0.024607, Risk = 0.072997
# K: Exp ret = 0.002013, Risk = 0.039679
# AVGO: Exp ret = 0.048521, Risk = 0.076502
# NCLH: Exp ret = 0.053027, Risk = 0.202789
# BIIB: Exp ret = -0.008635, Risk = 0.097898
# MMC: Exp ret = 0.029824, Risk = 0.060842
# BRO: Exp ret = 0.029103, Risk = 0.055653
# CMCSA: Exp ret = 0.013512, Risk = 0.078357
# EQR: Exp ret = 0.016144, Risk = 0.074999
# VNO: Exp ret = 0.014225, Risk = 0.092616
# HES: Exp ret = 0.058407, Risk = 0.133363
# DPZ: Exp ret = 0.015289, Risk = 0.079942
# EL: Exp ret = 0.028875, Risk = 0.086535
# JNPR: Exp ret = 0.027842, Risk = 0.073652
# AAPL: Exp ret = 0.046072, Risk = 0.097513
# SEDG: Exp ret = 0.074183, Risk = 0.170133
# NRG: Exp ret = 0.023557, Risk = 0.113098
# KMI: Exp ret = 0.022015, Risk = 0.080496
# AEP: Exp ret = 0.006629, Risk = 0.065289
# IQV: Exp ret = 0.043257, Risk = 0.097674
# ICE: Exp ret = 0.025396, Risk = 0.069355
# SRE: Exp ret = 0.017293, Risk = 0.059522
# IPGP: Exp ret = 0.010567, Risk = 0.116677
# GPC: Exp ret = 0.028802, Risk = 0.072047
# ES: Exp ret = 0.003449, Risk = 0.058479
# WRK: Exp ret = 0.026227, Risk = 0.083519
# LUV: Exp ret = 0.018292, Risk = 0.110249
# CDNS: Exp ret = 0.046545, Risk = 0.095499
# CSX: Exp ret = 0.027471, Risk = 0.070401
# TGT: Exp ret = 0.035565, Risk = 0.073681
# BR: Exp ret = 0.021243, Risk = 0.071788
# FANG: Exp ret = 0.103410, Risk = 0.199803
# ANSS: Exp ret = 0.018134, Risk = 0.077794
# TSCO: Exp ret = 0.044963, Risk = 0.080580
# FIS: Exp ret = -0.000016, Risk = 0.099289
# HPE: Exp ret = 0.025040, Risk = 0.080686
# ACN: Exp ret = 0.031436, Risk = 0.078188
# CPB: Exp ret = -0.001714, Risk = 0.048156
# SO: Exp ret = 0.011012, Risk = 0.053573
# NEE: Exp ret = 0.019093, Risk = 0.066982
# CRL: Exp ret = 0.045822, Risk = 0.103001
# CCI: Exp ret = 0.013510, Risk = 0.079435
# GS: Exp ret = 0.037482, Risk = 0.096060
# CTAS: Exp ret = 0.033879, Risk = 0.093366
# PSA: Exp ret = 0.029086, Risk = 0.059718
# KEY: Exp ret = 0.041425, Risk = 0.083770
# WRB: Exp ret = 0.026632, Risk = 0.054252
# FBHS: Exp ret = 0.038771, Risk = 0.106010

# %%
# Number of variables
n = len(symbols)

# The variables vector
x = Variable(n)

# The minimum return
req_return = 0.04

# The return
ret = r.T@x

# The risk in xT.Q.x format
risk = quad_form(x, C)

# The core problem definition with the Problem class from CVXPY
constraints = [sum(x)==1, ret >= req_return, x >= 0]
#prob = Problem(Minimize(risk), constraints)
prob = Problem(Minimize(risk), constraints)

try:
    prob.solve()
    print ("Optimal portfolio")
    print ("----------------------")
    for s in range(len(symbols)):
        if(round(100*x.value[s]) > 0.0001):
            print (" Investment in {} : {}% of the portfolio".format(symbols[s],round(100*x.value[s])))
    print ("----------------------")
    print ("Exp ret = {}%".format(round(100*ret.value,2)))
    print ("Expected risk    = {}%".format(round(100*risk.value**0.5,2)))
except:
    print ("Error")
# Out:
# Optimal portfolio
# ----------------------
#  Investment in CF : 7% of the portfolio
#  Investment in NTAP : 2% of the portfolio
#  Investment in VMC : 1% of the portfolio
#  Investment in QCOM : 6% of the portfolio
#  Investment in HPQ : 2% of the portfolio
#  Investment in ED : 8% of the portfolio
#  Investment in CTRA : 5% of the portfolio
#  Investment in ADM : 14% of the portfolio
#  Investment in MOS : 2% of the portfolio
#  Investment in MPWR : 20% of the portfolio
#  Investment in OXY : 4% of the portfolio
#  Investment in COP : 2% of the portfolio
#  Investment in PSA : 26% of the portfolio
# ----------------------
# Exp ret = 4.0%
# Expected risk    = 2.29%

# %%
prob.status
# Out:
# 'optimal'

# %%
# Number of variables
n = len(symbols)

# The variables vector
x = Variable(n)

y = Variable(n, boolean=True)


# The minimum return
req_return = 0.01

# The return
ret = r.T@x

# The risk in xT.Q.x format
risk = quad_form(x, C)

# The core problem definition with the Problem class from CVXPY
constraints += [sum(x)==1, ret >= req_return, x >= 0]
#constraints += [x[466] >= 0.25]
#constraints += [x[375] >= 0.05]

#prob = Problem(Minimize(risk), constraints)
prob = Problem(Minimize(risk), constraints)

try:
    prob.solve()
    print ("Optimal portfolio")
    print ("----------------------")
    for s in range(len(symbols)):
        if(round(100*x.value[s]) > 0.0001):
            print (" Investment in {} : {}% of the portfolio".format(symbols[s],round(100*x.value[s])))
    print ("----------------------")
    print ("Exp ret = {}%".format(round(100*ret.value,2)))
    print ("Expected risk    = {}%".format(round(100*risk.value**0.5,2)))
except:
    print ("Error")
# Out:
# Optimal portfolio
# ----------------------
#  Investment in CINF : 1341% of the portfolio
#  Investment in NTAP : 170% of the portfolio
#  Investment in TXN : 174% of the portfolio
#  Investment in VMC : 656% of the portfolio
#  Investment in PG : 125% of the portfolio
#  Investment in QCOM : 556% of the portfolio
#  Investment in TMUS : 951% of the portfolio
#  Investment in RMD : 53% of the portfolio
#  Investment in ED : 1679% of the portfolio
#  Investment in CTRA : 1546% of the portfolio
#  Investment in HAS : 10% of the portfolio
#  Investment in MPWR : 664% of the portfolio
#  Investment in COST : 52% of the portfolio
#  Investment in ADBE : 268% of the portfolio
#  Investment in FE : 1653% of the portfolio
#  Investment in LUV : 105% of the portfolio
# ----------------------
# Exp ret = 200.25%
# Expected risk    = 148.56%

# %%
mu = r
sigma =  np.random.randn(mu.shape[0], mu.shape[0])
sigma = sigma.T @ sigma

# %%
# Number of variables
n = len(symbols)

# The variables vector
x = Variable(n)

# The minimum return
req_return = 0.1

# The return
ret = r.T@x

# The risk in xT.Q.x format
risk = quad_form(x, C)

gamma = Parameter()

# The core problem definition with the Problem class from CVXPY
constraints += [sum(x)==1, ret >= req_return, x >= 0]
#constraints += [x[466] >= 0.05]
#constraints += [x[375] >= 0.05]

#prob = Problem(Minimize(risk), constraints)

exp_ret = []
exp_risk = []
exp_risk_ret = []
try:
    SAMPLES = 25
    gamma_vals = np.logspace(-1, 1, num=SAMPLES)
    for i in range(SAMPLES):        
        prob = Problem(Maximize(ret-gamma_vals[i]*risk), constraints)
        prob.solve()
        exp_ret.append(round(100*ret.value,2))
        exp_risk.append(round(100*risk.value**0.5,2))         
except:
    print ("Error")
    
    
plt.plot(exp_ret)
plt.plot(exp_risk) 
plt.plot(exp_risk_ret) 
plt.show()
# Out:
# C:\Users\GudiduriSS\Anaconda3\lib\site-packages\cvxpy\problems\problem.py:1333: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(

# %%
prob = Problem(Maximize(ret-gamma_vals[16]*risk), constraints)
df = pd.DataFrame(list(), columns=["Symbol", "investment"])

try:
    prob.solve()
    print ("Optimal portfolio")
    print ("----------------------")
    for s in range(len(symbols)):
        if(round(100*x.value[s]) > .1):
            df.loc[len(df.index)] = [symbols[s], round(100*x.value[s])]
            print (" Investment in {} : {}% of the portfolio".format(symbols[s],round(100*x.value[s])))
    print ("----------------------")
    print ("Exp ret = {}%".format(round(100*ret.value,2)))
    print ("Expected risk    = {}%".format(round(100*risk.value**0.5,2)))
except:
    print ("Error")
# Out:
# Optimal portfolio
# ----------------------
#  Investment in BBWI : 6% of the portfolio
#  Investment in NVDA : 7% of the portfolio
#  Investment in ENPH : 3% of the portfolio
#  Investment in FCX : 25% of the portfolio
#  Investment in DVN : 20% of the portfolio
#  Investment in MRNA : 4% of the portfolio
#  Investment in MOS : 25% of the portfolio
#  Investment in CZR : 4% of the portfolio
#  Investment in TSLA : 8% of the portfolio
# ----------------------
# Exp ret = 10.0%
# Expected risk    = 10.92%

# %%
ret-gamma_vals[16]
# Out:
# Expression(AFFINE, UNKNOWN, ())

# %%
df = df.merge(sp_index, left_on='Symbol', right_on='Symbol')

# %%
df = df.sort_values(by=['investment'], ascending=False)
df
# Out:
#   Symbol investment                    Company    Weight    Price    Chg
# 3    FCX         25      Freeport-McMoRan Inc.  0.193863    51.00   1.81
# 6    MOS         25             Mosaic Company  0.075736    79.00   2.95
# 4    DVN         20   Devon Energy Corporation  0.105710    63.69   1.13
# 8   TSLA          8                  Tesla Inc  2.220094  1009.60  24.60
# 1   NVDA          7         NVIDIA Corporation  1.430872   219.63   7.05
# 0   BBWI          6     Bath & Body Works Inc.  0.037076    52.91   0.72
# 5   MRNA          4               Moderna Inc.  0.156956   156.48  -9.01
# 7    CZR          4  Caesars Entertainment Inc  0.039666    68.37  -0.51
# 2   ENPH          3        Enphase Energy Inc.  0.068835   190.74   0.23

# %%
df["AllocatedAmount"] = (df["investment"]/100)*1000

# %%
df["purchasePower"] = (df["AllocatedAmount"]/df["Price"]).astype(int)

# %%
df[df["purchasePower"] > 0.0]
# Out:
#   Symbol investment                   Company    Weight  Price   Chg  \
# 3    FCX         25     Freeport-McMoRan Inc.  0.193863  51.00  1.81
# 6    MOS         25            Mosaic Company  0.075736  79.00  2.95
# 4    DVN         20  Devon Energy Corporation  0.105710  63.69  1.13
# 0   BBWI          6    Bath & Body Works Inc.  0.037076  52.91  0.72
#
#   AllocatedAmount  purchasePower
# 3           250.0              4
# 6           250.0              3
# 4           200.0              3
# 0            60.0              1

# %%
#companies to invest
must_invest = [ "AAPL", "NFLX"]

#companies to not invest
must_not_invest = ["TSLA"]


# Number of variables
n = len(symbols)

# The variables vector
x = Variable(n)


# The minimum return
req_return = 0.05

# The return
ret = r.T@x

# The risk in xT.Q.x format
risk = quad_form(x, C)

constraints = []
# The core problem definition with the Problem class from CVXPY
constraints += [sum(x)==1, ret >= req_return, x >= 0]

## Include stocks that you have choosen.
for i in must_invest:
    ind = list(symbols).index(i)
    constraints += [x[ind] >= 0.25]

## remove stocks that you have choosen.
for i in must_not_invest:
    ind = list(symbols).index(i)
    constraints += [x[ind] <= .00]

#prob = Problem(Minimize(risk), constraints)
# as theta increases risk is removed from equation
# as theta decreases risk is increased from equation
prob = Problem(Maximize(ret-1.5*risk), constraints)

try:
    prob.solve()
    print ("Optimal portfolio")
    print ("----------------------")
    for s in range(len(symbols)):
        if(round(100*x.value[s]) > 0.0001):
            print (" Investment in {} : {}% of the portfolio".format(symbols[s],round(100*x.value[s])))
    print ("----------------------")
    print ("Exp ret = {}%".format(round(100*ret.value,2)))
    print ("Expected risk    = {}%".format(round(100*risk.value**0.5,2)))
except:
    print ("Error")
# Out:
# Optimal portfolio
# ----------------------
#  Investment in FCX : 20% of the portfolio
#  Investment in DVN : 20% of the portfolio
#  Investment in NFLX : 25% of the portfolio
#  Investment in CZR : 8% of the portfolio
#  Investment in PENN : 3% of the portfolio
#  Investment in AAPL : 25% of the portfolio
# ----------------------
# Exp ret = 7.05%
# Expected risk    = 9.84%

# %%
#companies to invest
must_invest = [ "AAPL", "NFLX"]

#companies to not invest
must_not_invest = ["TSLA"]


# Number of variables
n = len(symbols)

# The variables vector
x = Variable(n)


# The minimum return
req_return = 0.05

# The return
ret = r.T@x

p = []
for i in list(symbols):
    p.append(int(sp_index[sp_index["Symbol"]==i]["Price"]))


p = np.array(p)

temp = p.T@(x)

# The risk in xT.Q.x format
risk = quad_form(x, C)

constraints = []
# The core problem definition with the Problem class from CVXPY
constraints += [sum(x) == 1, ret >= req_return, temp <= 5000, x >= 0, sum(temp) <= 20000]

## Include stocks that you have choosen.
for i in must_invest:
    ind = list(symbols).index(i)
    constraints += [x[ind] >= 0.25]

## remove stocks that you have choosen.
for i in must_not_invest:
    ind = list(symbols).index(i)
    constraints += [x[ind] <= .00]
    


#prob = Problem(Minimize(risk), constraints)
# as theta increases risk is removed from equation
# as theta decreases risk is increased from equation
prob = Problem(Maximize(ret-1.5*risk), constraints)

try:
    prob.solve()
    print ("Optimal portfolio")
    print ("----------------------")
    for s in range(len(symbols)):
        if(round(100*x.value[s]) > 0.01):
            print (" Investment in {} : {}% of the portfolio".format(symbols[s],round(100*x.value[s])))
    print ("----------------------")
    print ("Exp ret = {}%".format(round(100*ret.value,2)))
    print ("Expected risk    = {}%".format(round(100*risk.value**0.5,2)))
except:
    print ("Error")
# Out:
# Optimal portfolio
# ----------------------
#  Investment in FCX : 20% of the portfolio
#  Investment in DVN : 19% of the portfolio
#  Investment in NFLX : 25% of the portfolio
#  Investment in CZR : 8% of the portfolio
#  Investment in PENN : 3% of the portfolio
#  Investment in AAPL : 25% of the portfolio
# ----------------------
# Exp ret = 7.0%
# Expected risk    = 9.8%

# %%
price = []
for i in list(symbols):
    price.append(int(sp_index[sp_index["Symbol"]==i]["Price"]))


price = np.array(price)
price.shape
# Out:
# (500,)
