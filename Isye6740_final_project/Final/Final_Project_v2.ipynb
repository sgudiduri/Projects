# %% [markdown]
# ## 1.Load S&P data

# %%
import Loader as loader
from StockMarketInvestor import StockMarketInvestor

# %%
sp_comp = loader.get_sp_index()
print("S&P Companies")
sp_comp.head()
# Out:
# S&P Companies
#                  Company Symbol    Weight    Price    Chg
# 0             Apple Inc.   AAPL  6.878571   167.80   0.40
# 1  Microsoft Corporation   MSFT  5.669560   286.89   1.59
# 2        Amazon.com Inc.   AMZN  3.668142  3092.00 -70.31
# 3              Tesla Inc   TSLA  2.281229  1028.40   0.25
# 4  Alphabet Inc. Class A  GOOGL  2.072692  2571.95 -28.23

# %%
#Peek at data
sp_hist = loader.get_ticker_historical(list(sp_comp["Symbol"]))
print("S&P Historical Data")
sp_hist[["AMZN","TSLA", "AAPL", "NFLX"]].tail()
# Out:
# S&P Historical Data
#                    AMZN         TSLA        AAPL        NFLX
# Date
# 2022-03-24  3272.989990  1013.919983  174.070007  375.709991
# 2022-03-25  3295.469971  1010.640015  174.720001  373.850006
# 2022-03-28  3379.810059  1091.839966  175.600006  378.510010
# 2022-03-29  3386.300049  1099.569946  178.960007  391.820007
# 2022-03-30  3326.020020  1093.989990  177.770004  381.470001

# %%
print("S&P Historical Data statistical description")
sm_list = ["AMZN","TSLA", "AAPL", "NFLX"]
sp_hist_short = sp_hist[sm_list]
sp_hist_short.describe()
# Out:
# S&P Historical Data statistical description
#               AMZN         TSLA        AAPL        NFLX
# count   513.000000   513.000000  513.000000  513.000000
# mean   3131.497037   623.689936  128.451540  507.627290
# std     370.562331   284.574884   29.307192   76.135233
# min    1846.089966    85.505997   56.092499  331.010010
# 25%    3057.159912   415.089996  115.050003  476.260010
# 50%    3217.010010   663.690002  129.639999  508.820007
# 75%    3355.729980   818.320007  148.759995  546.989990
# max    3731.409912  1229.910034  182.009995  691.690002

# %% [markdown]
# ## 2.Visualize Price and Monthly returns

# %%
sp_hist_short.plot(figsize=(10,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
sp_hist_short.pct_change(30).dropna().plot(figsize=(10, 6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
sp_hist_short.boxplot(figsize=(10, 6))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 3. Run Stock Market Investor
#
# ### a) Run without constrains

# %%
import warnings
warnings.filterwarnings("ignore")

sm = StockMarketInvestor(sp_hist, 0.1)
sm.train()
# Out:
# Optimal gamma @ 2.1544346900318834

# %%
ret = sm.optimize()
# Out:
# Optimal portfolio
# ----------------------
#  Investment in BBWI : 6% of the portfolio
#  Investment in NVDA : 6% of the portfolio
#  Investment in ENPH : 3% of the portfolio
#  Investment in FCX : 25% of the portfolio
#  Investment in DVN : 20% of the portfolio
#  Investment in MRNA : 4% of the portfolio
#  Investment in MOS : 25% of the portfolio
#  Investment in CZR : 4% of the portfolio
#  Investment in TSLA : 9% of the portfolio
# ----------------------
# Exp ret = 10.0%
# Expected risk    = 10.97%

# %% [markdown]
# ### b) Run with constrains include

# %%
sm = StockMarketInvestor(sp_hist, 0.05, include=['AAPL'])
sm.train()
# Out:
# Optimal gamma @ 2.1544346900318834

# %%
ret = sm.optimize()
# Out:
# Optimal portfolio
# ----------------------
#  Investment in BBWI : 4% of the portfolio
#  Investment in NVDA : 11% of the portfolio
#  Investment in ENPH : 3% of the portfolio
#  Investment in FCX : 23% of the portfolio
#  Investment in DVN : 18% of the portfolio
#  Investment in MRNA : 4% of the portfolio
#  Investment in MOS : 28% of the portfolio
#  Investment in CZR : 2% of the portfolio
#  Investment in TSLA : 5% of the portfolio
#  Investment in AAPL : 1% of the portfolio
# ----------------------
# Exp ret = 9.6%
# Expected risk    = 10.11%

# %% [markdown]
# ### b) Run with constrains include and exclude

# %%
sm = StockMarketInvestor(sp_hist, 0.05, include=['AAPL'], exclude=['TSLA','FCX'])
sm.train()
# Out:
# Optimal gamma @ 2.1544346900318834

# %%
ret = sm.optimize()
ret = ret.merge(sp_comp, left_on='Symbol', right_on='Symbol')
# Out:
# Optimal portfolio
# ----------------------
#  Investment in BBWI : 6% of the portfolio
#  Investment in NVDA : 14% of the portfolio
#  Investment in ENPH : 7% of the portfolio
#  Investment in DVN : 23% of the portfolio
#  Investment in MRNA : 7% of the portfolio
#  Investment in MOS : 42% of the portfolio
#  Investment in CZR : 2% of the portfolio
#  Investment in AAPL : 1% of the portfolio
# ----------------------
# Exp ret = 9.27%
# Expected risk    = 9.62%

# %%
ret = ret.sort_values(by="InvestmentPercentage", ascending=False)

# %% [markdown]
# ## USE LSTM To predict stock ticker, Can we make selections at individual level

# %%
#choose top 4 stocks for prediction
sel_lst = list(ret["Symbol"][:5])
print(f"Choosen stocks: {sel_lst}")
sel_hist = sp_hist[sel_lst]
# Out:
# Choosen stocks: ['MOS', 'DVN', 'NVDA', 'ENPH', 'MRNA']

# %%
sp_comp[sp_comp["Symbol"].isin(sel_hist)]
# Out:
#                       Company Symbol    Weight   Price    Chg
# 7          NVIDIA Corporation   NVDA  1.470847  216.23  -5.76
# 148              Moderna Inc.   MRNA  0.142583  150.60  -2.12
# 204  Devon Energy Corporation    DVN  0.104791   64.80   1.80
# 265            Mosaic Company    MOS  0.076447   75.51  -2.47
# 286       Enphase Energy Inc.   ENPH  0.069573  179.09 -16.51

# %%
mos = sel_hist["NVDA"].reset_index().drop(columns=["Date"])

# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0,1))
mos = scaler.fit_transform(np.array(mos).reshape(-1,1))

# %%
#split into training and test data splits
xtrs = int(len(mos)*0.80)
xtss = len(mos) - xtrs
train, test = mos[0:xtrs, :],  mos[xtrs:, :1]

# %%
print(train.shape,test.shape)
# Out:
# (410, 1) (103, 1)

# %%
def create_features_targets(ds, time_step=1):
    X, y= [], []
    tf = len(ds)-time_step-1
    for i in range(tf):
        X.append(ds[i:(i+time_step),0])
        y.append(ds[(i+time_step),0])    
    return np.array(X), np.array(y)

# %%
time_step = 60
X_train, y_train = create_features_targets(train, time_step)
X_test, ytest = create_features_targets(test, time_step)\
# reshape input to be [samples, time steps, features] which is required for LSTM
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# %%
print(X_train.shape, y_train.shape, X_test.shape, ytest.shape)
# Out:
# (349, 60, 1) (349,) (42, 60, 1) (42,)

# %%
### Create the Stacked LSTM model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

# %%
model=Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(X_train.shape[1],1)))
model.add(LSTM(50,return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')

# %%
model.fit(X_train,y_train,validation_data=(X_test,ytest),epochs=100,batch_size=64,verbose=1)
# Out:
# Epoch 1/100
# 6/6 [==============================] - 4s 223ms/step - loss: 0.1072 - val_loss: 0.1082
# Epoch 2/100
# 6/6 [==============================] - 0s 74ms/step - loss: 0.0172 - val_loss: 0.0063
# Epoch 3/100
# 6/6 [==============================] - 0s 78ms/step - loss: 0.0069 - val_loss: 0.0666
# Epoch 4/100
# 6/6 [==============================] - 0s 80ms/step - loss: 0.0089 - val_loss: 0.0205
# Epoch 5/100
# 6/6 [==============================] - 1s 88ms/step - loss: 0.0058 - val_loss: 0.0075
# Epoch 6/100
# 6/6 [==============================] - 0s 83ms/step - loss: 0.0042 - val_loss: 0.0249
# Epoch 7/100
# 6/6 [==============================] - 0s 84ms/step - loss: 0.0038 - val_loss: 0.0106
# Epoch 8/100
# 6/6 [==============================] - 1s 86ms/step - loss: 0.0025 - val_loss: 0.0058
# Epoch 9/100
# 6/6 [==============================] - 0s 83ms/step - loss: 0.0019 - val_loss: 0.0068
# Epoch 10/100
# 6/6 [==============================] - 0s 77ms/step - loss: 0.0015 - val_loss: 0.0064
# Epoch 11/100
# 6/6 [==============================] - 0s 72ms/step - loss: 0.0014 - val_loss: 0.0068
# Epoch 12/100
# 6/6 [==============================] - 0s 69ms/step - loss: 0.0014 - val_loss: 0.0080
# Epoch 13/100
# 6/6 [==============================] - 0s 71ms/step - loss: 0.0014 - val_loss: 0.0074
# Epoch 14/100
# 6/6 [==============================] - 0s 71ms/step - loss: 0.0015 - val_loss: 0.0078
# Epoch 15/100
# 6/6 [==============================] - 0s 70ms/step - loss: 0.0016 - val_loss: 0.0060
# Epoch 16/100
# 6/6 [==============================] - 0s 71ms/step - loss: 0.0015 - val_loss: 0.0070
# Epoch 17/100
# 6/6 [==============================] - 0s 69ms/step - loss: 0.0014 - val_loss: 0.0060
# Epoch 18/100
# 6/6 [==============================] - 0s 71ms/step - loss: 0.0014 - val_loss: 0.0067
# Epoch 19/100
# 6/6 [==============================] - 0s 69ms/step - loss: 0.0014 - val_loss: 0.0061
# Epoch 20/100
# 6/6 [==============================] - 0s 70ms/step - loss: 0.0013 - val_loss: 0.0066
# Epoch 21/100
# 6/6 [==============================] - 0s 73ms/step - loss: 0.0014 - val_loss: 0.0060
# Epoch 22/100
# 6/6 [==============================] - 0s 70ms/step - loss: 0.0013 - val_loss: 0.0063
# Epoch 23/100
# 6/6 [==============================] - 0s 71ms/step - loss: 0.0013 - val_loss: 0.0065
# Epoch 24/100
# 6/6 [==============================] - 0s 73ms/step - loss: 0.0013 - val_loss: 0.0064
# Epoch 25/100
# 6/6 [==============================] - 0s 71ms/step - loss: 0.0013 - val_loss: 0.0062
# Epoch 26/100
# 6/6 [==============================] - 0s 70ms/step - loss: 0.0013 - val_loss: 0.0068
# Epoch 27/100
# 6/6 [==============================] - 0s 70ms/step - loss: 0.0013 - val_loss: 0.0061
# Epoch 28/100
# 6/6 [==============================] - 0s 70ms/step - loss: 0.0013 - val_loss: 0.0065
# Epoch 29/100
# 6/6 [==============================] - 0s 81ms/step - loss: 0.0013 - val_loss: 0.0060
# Epoch 30/100
# 6/6 [==============================] - 0s 74ms/step - loss: 0.0013 - val_loss: 0.0073
# Epoch 31/100
# 6/6 [==============================] - 0s 70ms/step - loss: 0.0013 - val_loss: 0.0057
# Epoch 32/100
# 6/6 [==============================] - 0s 70ms/step - loss: 0.0014 - val_loss: 0.0072
# Epoch 33/100
# 6/6 [==============================] - 0s 72ms/step - loss: 0.0014 - val_loss: 0.0061
# Epoch 34/100
# 6/6 [==============================] - 0s 71ms/step - loss: 0.0013 - val_loss: 0.0056
# Epoch 35/100
# 6/6 [==============================] - 0s 71ms/step - loss: 0.0013 - val_loss: 0.0067
# Epoch 36/100
# 6/6 [==============================] - 0s 70ms/step - loss: 0.0013 - val_loss: 0.0056
# Epoch 37/100
# 6/6 [==============================] - 0s 69ms/step - loss: 0.0012 - val_loss: 0.0067
# Epoch 38/100
# 6/6 [==============================] - 0s 71ms/step - loss: 0.0013 - val_loss: 0.0058
# Epoch 39/100
# 6/6 [==============================] - 0s 78ms/step - loss: 0.0012 - val_loss: 0.0071
# Epoch 40/100
# 6/6 [==============================] - 0s 80ms/step - loss: 0.0013 - val_loss: 0.0057
# Epoch 41/100
# 6/6 [==============================] - 1s 86ms/step - loss: 0.0012 - val_loss: 0.0058
# Epoch 42/100
# 6/6 [==============================] - 1s 90ms/step - loss: 0.0012 - val_loss: 0.0066
# Epoch 43/100
# 6/6 [==============================] - 0s 81ms/step - loss: 0.0013 - val_loss: 0.0055
# Epoch 44/100
# 6/6 [==============================] - 1s 96ms/step - loss: 0.0014 - val_loss: 0.0055
# Epoch 45/100
# 6/6 [==============================] - 1s 86ms/step - loss: 0.0012 - val_loss: 0.0064
# Epoch 46/100
# 6/6 [==============================] - 0s 75ms/step - loss: 0.0012 - val_loss: 0.0054
# Epoch 47/100
# 6/6 [==============================] - 0s 72ms/step - loss: 0.0012 - val_loss: 0.0058
# Epoch 48/100
# 6/6 [==============================] - 0s 83ms/step - loss: 0.0012 - val_loss: 0.0057
# Epoch 49/100
# 6/6 [==============================] - 1s 83ms/step - loss: 0.0012 - val_loss: 0.0053
# Epoch 50/100
# 6/6 [==============================] - 1s 85ms/step - loss: 0.0012 - val_loss: 0.0066
# Epoch 51/100
# 6/6 [==============================] - 0s 70ms/step - loss: 0.0012 - val_loss: 0.0053
# Epoch 52/100
# 6/6 [==============================] - 0s 70ms/step - loss: 0.0012 - val_loss: 0.0052
# Epoch 53/100
# 6/6 [==============================] - 0s 72ms/step - loss: 0.0012 - val_loss: 0.0053
# Epoch 54/100
# 6/6 [==============================] - 0s 73ms/step - loss: 0.0011 - val_loss: 0.0058
# Epoch 55/100
# 6/6 [==============================] - 0s 70ms/step - loss: 0.0012 - val_loss: 0.0053
# Epoch 56/100
# 6/6 [==============================] - 0s 72ms/step - loss: 0.0011 - val_loss: 0.0066
# Epoch 57/100
# 6/6 [==============================] - 0s 73ms/step - loss: 0.0011 - val_loss: 0.0051
# Epoch 58/100
# 6/6 [==============================] - 0s 71ms/step - loss: 0.0011 - val_loss: 0.0051
# Epoch 59/100
# 6/6 [==============================] - 0s 79ms/step - loss: 0.0011 - val_loss: 0.0052
# Epoch 60/100
# 6/6 [==============================] - 0s 82ms/step - loss: 0.0011 - val_loss: 0.0056
# Epoch 61/100
# 6/6 [==============================] - 0s 83ms/step - loss: 0.0011 - val_loss: 0.0053
# Epoch 62/100
# 6/6 [==============================] - 0s 81ms/step - loss: 0.0011 - val_loss: 0.0053
# Epoch 63/100
# 6/6 [==============================] - 0s 79ms/step - loss: 0.0010 - val_loss: 0.0049
# Epoch 64/100
# 6/6 [==============================] - 0s 80ms/step - loss: 0.0010 - val_loss: 0.0049
# Epoch 65/100
# 6/6 [==============================] - 0s 82ms/step - loss: 0.0010 - val_loss: 0.0054
# Epoch 66/100
# 6/6 [==============================] - 0s 80ms/step - loss: 0.0010 - val_loss: 0.0048
# Epoch 67/100
# 6/6 [==============================] - 0s 79ms/step - loss: 0.0010 - val_loss: 0.0048
# Epoch 68/100
# 6/6 [==============================] - 0s 82ms/step - loss: 9.5470e-04 - val_loss: 0.0048
# Epoch 69/100
# 6/6 [==============================] - 0s 80ms/step - loss: 9.4146e-04 - val_loss: 0.0058
# Epoch 70/100
# 6/6 [==============================] - 0s 81ms/step - loss: 0.0010 - val_loss: 0.0048
# Epoch 71/100
# 6/6 [==============================] - 0s 80ms/step - loss: 9.9857e-04 - val_loss: 0.0049
# Epoch 72/100
# 6/6 [==============================] - 0s 82ms/step - loss: 9.5789e-04 - val_loss: 0.0056
# Epoch 73/100
# 6/6 [==============================] - 1s 86ms/step - loss: 0.0010 - val_loss: 0.0048
# Epoch 74/100
# 6/6 [==============================] - 1s 89ms/step - loss: 9.6894e-04 - val_loss: 0.0048
# Epoch 75/100
# 6/6 [==============================] - 1s 97ms/step - loss: 8.8632e-04 - val_loss: 0.0045
# Epoch 76/100
# 6/6 [==============================] - 1s 97ms/step - loss: 8.7072e-04 - val_loss: 0.0044
# Epoch 77/100
# 6/6 [==============================] - 1s 89ms/step - loss: 8.2143e-04 - val_loss: 0.0044
# Epoch 78/100
# 6/6 [==============================] - 1s 97ms/step - loss: 7.7441e-04 - val_loss: 0.0044
# Epoch 79/100
# 6/6 [==============================] - 1s 94ms/step - loss: 7.7489e-04 - val_loss: 0.0049
# Epoch 80/100
# 6/6 [==============================] - 1s 90ms/step - loss: 7.9988e-04 - val_loss: 0.0053
# Epoch 81/100
# 6/6 [==============================] - 0s 83ms/step - loss: 6.9965e-04 - val_loss: 0.0103
# Epoch 82/100
# 6/6 [==============================] - 0s 81ms/step - loss: 7.9535e-04 - val_loss: 0.0076
# Epoch 83/100
# 6/6 [==============================] - 0s 78ms/step - loss: 6.6716e-04 - val_loss: 0.0076
# Epoch 84/100
# 6/6 [==============================] - 0s 80ms/step - loss: 6.7037e-04 - val_loss: 0.0073
# Epoch 85/100
# 6/6 [==============================] - 0s 81ms/step - loss: 6.9269e-04 - val_loss: 0.0110
# Epoch 86/100
# 6/6 [==============================] - 0s 78ms/step - loss: 6.5824e-04 - val_loss: 0.0084
# Epoch 87/100
# 6/6 [==============================] - 0s 83ms/step - loss: 7.5332e-04 - val_loss: 0.0077
# Epoch 88/100
# 6/6 [==============================] - 1s 85ms/step - loss: 7.4123e-04 - val_loss: 0.0075
# Epoch 89/100
# 6/6 [==============================] - 0s 81ms/step - loss: 6.5618e-04 - val_loss: 0.0077
# Epoch 90/100
# 6/6 [==============================] - 0s 83ms/step - loss: 6.5543e-04 - val_loss: 0.0068
# Epoch 91/100
# 6/6 [==============================] - 0s 84ms/step - loss: 6.4779e-04 - val_loss: 0.0057
# Epoch 92/100
# 6/6 [==============================] - 0s 81ms/step - loss: 7.0904e-04 - val_loss: 0.0068
# Epoch 93/100
# 6/6 [==============================] - 0s 83ms/step - loss: 6.5659e-04 - val_loss: 0.0083
# Epoch 94/100
# 6/6 [==============================] - 0s 79ms/step - loss: 6.5154e-04 - val_loss: 0.0064
# Epoch 95/100
# 6/6 [==============================] - 0s 81ms/step - loss: 6.1903e-04 - val_loss: 0.0067
# Epoch 96/100
# 6/6 [==============================] - 0s 79ms/step - loss: 6.0965e-04 - val_loss: 0.0067
# Epoch 97/100
# 6/6 [==============================] - 0s 79ms/step - loss: 6.2174e-04 - val_loss: 0.0145
# Epoch 98/100
# 6/6 [==============================] - 0s 78ms/step - loss: 6.5936e-04 - val_loss: 0.0139
# Epoch 99/100
# 6/6 [==============================] - 0s 81ms/step - loss: 6.2343e-04 - val_loss: 0.0091
# Epoch 100/100
# 6/6 [==============================] - 0s 79ms/step - loss: 6.0902e-04 - val_loss: 0.0078

# %%
##Transformback to original form
train_predict=scaler.inverse_transform(model.predict(X_train))
test_predict=scaler.inverse_transform(model.predict(X_test))

# %%
### Calculate RMSE performance metrics
import math
from sklearn.metrics import mean_squared_error
math.sqrt(mean_squared_error(y_train,train_predict))
# Out:
# 156.2410926517359

# %%
### Test Data RMSE
math.sqrt(mean_squared_error(ytest,test_predict))
# Out:
# 249.0177486809174

# %%
import matplotlib.pyplot as plt
### Plotting 
# shift train predictions for plotting
look_back=60
trainPredictPlot = np.empty_like(mos)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(train_predict)+look_back, :] = train_predict
# shift test predictions for plotting
testPredictPlot = np.empty_like(mos)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(train_predict)+(look_back*2)+1:len(mos)-1, :] = test_predict
# plot baseline and predictions

plt.figure(figsize=(14,6))
plt.plot(scaler.inverse_transform(mos))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
